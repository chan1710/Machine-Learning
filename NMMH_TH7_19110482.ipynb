# %% [markdown]
# ## Môn: Nhập môn máy học
# * Bài thực hành: Lab07
# * Sinh vên: Huỳnh Thị Bảo Trân
# * MSSV: 19110482

# %% [markdown]
# # SVM

# %% [markdown]
# Trong notebook này, chúng ta sẽ chạy SVM trong dataset nhỏ

# %% [markdown]
# Hàm sau đây có nhiệm vụ nhận một data 2 chiều, label của nó và một hàm predict của model. Hàm có nhiệm vụ vẽ data, mỗi label có một kĩ hiệu riêng, đồng thời vẽ miền quyết định của classifier
# * `display_data_and_boundary(x,y,pred_fn)`
#
# trong đó
# * `x` và `y` là data 2 chiều và label tương ứng (label thuộc `0,...,k-1`)
# * `pred_fn` là classifier, là một hàm nhận input và trả về prediction

# %%
import os
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import numpy as np
from sklearn.svm import SVC
from sklearn import svm

# %%
def display_data_and_boundary(x, y, pred_fn):  
    # Determine the x1- and x2- limits of the plot
    x1min = min(x[:, 0]) - 1
    x1max = max(x[:, 0]) + 1
    x2min = min(x[:, 1]) - 1
    x2max = max(x[:, 1]) + 1
    plt.xlim(x1min, x1max)
    plt.ylim(x2min, x2max)

    # Plot the data points
    k = int(max(y)) + 1
    cols = ['ro', 'k^', 'b*','gx']
    for label in range(k):
        plt.plot(x[(y == label), 0], x[(y == label), 1], cols[label%4], markersize = 8)
        
    # Construct a grid of points at which to evaluate the classifier
    grid_spacing = 0.05
    xx1, xx2 = np.meshgrid(np.arange(x1min, x1max, grid_spacing), np.arange(x2min, x2max, grid_spacing))
    grid = np.c_[xx1.ravel(), xx2.ravel()]
    Z = np.array([pred_fn(pt) for pt in grid])
    
    # Show the classifier's boundary using a color plot
    Z = Z.reshape(xx1.shape)
    plt.pcolormesh(xx1, xx2, Z, cmap = plt.cm.Pastel1, vmin = 0, vmax = k)
    plt.show()

# %% [markdown]
# ## Thí nghiệm với SVM

# %% [markdown]
# Giờ chạy thử SVM và vẽ ra. Lưu ý đối với việc dùng các kernels như linear, polynomial ta chỉ cần quan tâm đến tham số C. Còn kernel rbf ta sẽ quan tâm thêm đến tham số $gamma$
#
# Khi $gamma$ càng lớn thì sẽ dẫn đến việc model sẽ chọn ra các miền quyết định quá khớp với dữ liệu huấn luyện

# %%
# Load IRIS data
from sklearn import datasets
iris = datasets.load_iris()
x = iris.data
y = iris.target

# Chọn ra 2 features để dễ vẽ hình
features = [0, 1]
x = x[:, features]

# Train SVM với kernel linear
clf = SVC(C = 1, kernel = 'linear')
clf.fit(x, y)
pred_fn = lambda p: clf.predict(p.reshape(1, -1))
display_data_and_boundary(x, y, pred_fn)

# %%
#Sử dụng kernel rbf với gamma lớn, ta có thể thấy các miền quyết định gần như fit vào các điểm dữ liệu
clf = svm.SVC(C = 1, kernel = 'rbf', gamma = 100)
clf.fit(x, y)
pred_fn = lambda p: clf.predict(p.reshape(1, -1))
display_data_and_boundary(x, y, pred_fn)

# %%
#Sử dụng kernel rbf, với gamma nhỏ ta thấy miền quyết định rộng hơn
clf = svm.SVC(C = 1, kernel = 'rbf', gamma = 0.5)
clf.fit(x, y)
pred_fn = lambda p: clf.predict(p.reshape(1, -1))
display_data_and_boundary(x, y, pred_fn)

# %% [markdown]
# #Bài Tập
# 1. Thử chạy SVM trên 2 files data_3.txt và data_4.txt với C=[0.1, 1.0, 10.0, 100.0]
#
# 2. Nhận xét với từng $C$ khác nhau thì mô hình thay đổi như thế nào
#
# 3. Nêu lợi và hại khi tăng $gamma$ và giảm $gamma$

# %%
# !wget https://raw.githubusercontent.com/huynhthanh98/ML/master/lab-10/data_3.txt #file data_3
# !wget https://raw.githubusercontent.com/huynhthanh98/ML/master/lab-10/data_4.txt #file data_4
# Out:
# --2022-06-09 07:10:45--  https://raw.githubusercontent.com/huynhthanh98/ML/master/lab-10/data_3.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2022-06-09 07:10:45 ERROR 404: Not Found.
#
# --2022-06-09 07:10:45--  https://raw.githubusercontent.com/huynhthanh98/ML/master/lab-10/data_4.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2022-06-09 07:10:45 ERROR 404: Not Found.

# %% [markdown]
# # 'Data_3.txt'

# %% [markdown]
# 1. Thử chạy SVM với $C=[0.1, 1.0, 10.0, 100.0]$

# %%
data = np.loadtxt('data_3.txt')
x = data[:, 0:2]
y = data[:, 2]

# %% [markdown]
# * C = 0.1

# %%
# kernel la linear
lf = SVC(C = 0.1, kernel = 'linear')
clf.fit(x, y)
pred_fn = lambda p: clf.predict(p.reshape(1, -1))
display_data_and_boundary(x, y, pred_fn)

# %%
# kernel la rbf, gamma lon
clf = svm.SVC(C = 0.1, kernel = 'rbf', gamma = 100)
clf.fit(x, y)
pred_fn = lambda p: clf.predict(p.reshape(1, -1))
display_data_and_boundary(x, y, pred_fn)

# %%
# kernel la rbf, gamma nho
clf = svm.SVC(C = 0.1, kernel = 'rbf', gamma = 0.5)
clf.fit(x, y)
pred_fn = lambda p: clf.predict(p.reshape(1, -1))
display_data_and_boundary(x, y, pred_fn)

# %% [markdown]
# * C = 1

# %%
data = np.loadtxt('data_3.txt')
x = data[:, 0:2]
y = data[:, 2]

# %%
# kernel la linear
lf = SVC(C = 1, kernel = 'linear')
clf.fit(x, y)
pred_fn = lambda p: clf.predict(p.reshape(1, -1))
display_data_and_boundary(x, y, pred_fn)

# %%
# kernel la rbf, gamma lon
clf = svm.SVC(C = 1, kernel = 'rbf', gamma = 100)
clf.fit(x, y)
pred_fn = lambda p: clf.predict(p.reshape(1, -1))
display_data_and_boundary(x, y, pred_fn)

# %%
# kernel la rbf, gamma nho
clf = svm.SVC(C = 1, kernel = 'rbf', gamma = 0.5)
clf.fit(x, y)
pred_fn = lambda p: clf.predict(p.reshape(1, -1))
display_data_and_boundary(x, y, pred_fn)

# %% [markdown]
# * C = 10

# %%
data = np.loadtxt('data_3.txt')
x = data[:, 0:2]
y = data[:, 2]

# %%
# kernel la linear
lf = SVC(C = 10, kernel = 'linear')
clf.fit(x, y)
pred_fn = lambda p: clf.predict(p.reshape(1, -1))
display_data_and_boundary(x, y, pred_fn)

# %%
# kernel la rbf, gamma lon
clf = svm.SVC(C = 10, kernel = 'rbf', gamma = 100)
clf.fit(x, y)
pred_fn = lambda p: clf.predict(p.reshape(1, -1))
display_data_and_boundary(x, y, pred_fn)

# %%
# kernel la rbf, gamma nho
clf = svm.SVC(C = 10, kernel = 'rbf', gamma = 0.5)
clf.fit(x, y)
pred_fn = lambda p: clf.predict(p.reshape(1, -1))
display_data_and_boundary(x, y, pred_fn)

# %% [markdown]
# * C = 100

# %%
data = np.loadtxt('data_3.txt')
x = data[:, 0:2]
y = data[:, 2]

# %%
# kernel la linear
lf = SVC(C = 100, kernel = 'linear')
clf.fit(x, y)
pred_fn = lambda p: clf.predict(p.reshape(1, -1))
display_data_and_boundary(x, y, pred_fn)

# %%
# kernel la rbf, gamma lon
clf = svm.SVC(C = 100, kernel = 'rbf', gamma = 100)
clf.fit(x, y)
pred_fn = lambda p: clf.predict(p.reshape(1, -1))
display_data_and_boundary(x, y, pred_fn)

# %%
# kernel la rbf, gamma nho
clf = svm.SVC(C = 100, kernel = 'rbf', gamma = 0.5)
clf.fit(x, y)
pred_fn = lambda p: clf.predict(p.reshape(1, -1))
display_data_and_boundary(x, y, pred_fn)

# %% [markdown]
# # 'Data_4.txt'

# %% [markdown]
# 1. Thử chạy SVM với $C = [0.1, 1.0, 10.0, 100.0]$

# %%
data = np.loadtxt('data_4.txt')
x = data[:, 0:2]
y = data[:, 2]

# %% [markdown]
# * C = 0.1

# %%
# kernel la linear
lf = SVC(C = 0.1, kernel = 'linear')
clf.fit(x, y)
pred_fn = lambda p: clf.predict(p.reshape(1, -1))
display_data_and_boundary(x, y, pred_fn)

# %%
# kernel la rbf, gamma lon
clf = svm.SVC(C = 0.1, kernel = 'rbf', gamma = 100)
clf.fit(x, y)
pred_fn = lambda p: clf.predict(p.reshape(1, -1))
display_data_and_boundary(x, y, pred_fn)

# %%
# kernel la rbf, gamma nho
clf = svm.SVC(C = 0.1, kernel = 'rbf', gamma = 0.5)
clf.fit(x, y)
pred_fn = lambda p: clf.predict(p.reshape(1, -1))
display_data_and_boundary(x, y, pred_fn)

# %% [markdown]
# * C = 1

# %%
data = np.loadtxt('data_4.txt')
x = data[:, 0:2]
y = data[:, 2]

# %%
# kernel la linear
lf = SVC(C = 1, kernel = 'linear')
clf.fit(x, y)
pred_fn = lambda p: clf.predict(p.reshape(1, -1))
display_data_and_boundary(x, y, pred_fn)

# %%
# kernel la rbf, gamma lon
clf = svm.SVC(C = 1, kernel = 'rbf', gamma = 100)
clf.fit(x, y)
pred_fn = lambda p: clf.predict(p.reshape(1, -1))
display_data_and_boundary(x, y, pred_fn)

# %%
# kernel la rbf, gamma nho
clf = svm.SVC(C = 1, kernel = 'rbf', gamma = 0.5)
clf.fit(x, y)
pred_fn = lambda p: clf.predict(p.reshape(1, -1))
display_data_and_boundary(x, y, pred_fn)

# %% [markdown]
# * C = 10

# %%
data = np.loadtxt('data_4.txt')
x = data[:, 0:2]
y = data[:, 2]

# %%
#kernel la linear
lf = SVC(C = 10, kernel = 'linear')
clf.fit(x, y)
pred_fn = lambda p: clf.predict(p.reshape(1, -1))
display_data_and_boundary(x, y, pred_fn)

# %%
# kernel la rbf, gamma lon
clf = svm.SVC(C = 10, kernel = 'rbf', gamma = 100)
clf.fit(x, y)
pred_fn = lambda p: clf.predict(p.reshape(1, -1))
display_data_and_boundary(x, y, pred_fn)

# %%
# kernel la rbf, gamma nho
clf = svm.SVC(C = 10, kernel = 'rbf', gamma = 0.5)
clf.fit(x, y)
pred_fn = lambda p: clf.predict(p.reshape(1, -1))
display_data_and_boundary(x, y, pred_fn)

# %% [markdown]
# * C = 100

# %%
data = np.loadtxt('data_4.txt')
x = data[:, 0:2]
y = data[:, 2]

# %%
# kernel la linear
lf = SVC(C = 100, kernel = 'linear')
clf.fit(x, y)
pred_fn = lambda p: clf.predict(p.reshape(1, -1))
display_data_and_boundary(x, y, pred_fn)

# %%
# kernel la rbf, gamma lon
clf = svm.SVC(C = 100, kernel = 'rbf', gamma = 100)
clf.fit(x, y)
pred_fn = lambda p: clf.predict(p.reshape(1, -1))
display_data_and_boundary(x, y, pred_fn)

# %%
# kernel la rbf, gamma nho
clf = svm.SVC(C = 100, kernel = 'rbf', gamma = 0.5)
clf.fit(x, y)
pred_fn = lambda p: clf.predict(p.reshape(1, -1))
display_data_and_boundary(x, y, pred_fn)

# %% [markdown]
# # Nhận xét:
# * Với từng C, ta thấy C ảnh hưởng trực tiếp tới model. Khi C càng lớn thì model càng fit với tập train, dễ dẫn tới trường hợp bị overfiting. Ngược lại, khi C giảm thì model sẽ ít fit với tập dữ liệu hơn. Đặc biệt khi C tăng thì biên phân lớp có xu hướng phức tạp hơn.
# * Nhìn chung, giá trị C cao hơn sẽ dẫn đến mô hình có độ chính xác rất cao nhưng có thể không tổng quát hóa được. Ngược lại, giá trị C thấp hơn sẽ dẫn đến một mô hình có độ chính xác rất thấp.
# * Với từng gamma, ta thấy gamma ảnh hưởng trực tiếp đến model. Khi gamma càng lớn thì miền quyết định gần như fit hoàn toàn với tập train. Ngược lại, khi C càng giảm thì miền quyết định càng rộng hơn.
# * Nhìn chung, giá trị gamma xác định mức độ ảnh hưởng của một ví dụ đào tạo duy nhất đạt đến bao xa. Các giá trị gamma thấp hơn dẫn đến các mô hình có độ chính xác thấp hơn và giống với các giá trị gamma cao hơn. Đó là các giá trị trung gian của gamma cung cấp cho một mô hình có ranh giới quyết định tốt.
